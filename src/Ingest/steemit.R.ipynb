# %%
path = '../../DataSources/raw/steemit/dumps/trending.json'

library(jsonlite)

# %%
trending <- fromJSON(path)
trending
# Out:
# Error in FUN(X[[i]], ...): attempt to use zero-length variable name
# Traceback:
#
# 1. tryCatch({
#  .     for (mime in getOption("jupyter.display_mimetypes")) {
#  .         r <- mime2repr[[mime]](obj)
#  .         if (!is.null(r))
#  .             data[[mime]] <- r
#  .     }
#  . }, error = handle_error)
# $current_route
# [1] "/trending"
#
# $props
# $props$id
# [1] 0
#
# $props$head_block_number
# [1] 11881033
#
# $props$head_block_id
# [1] "00b54a49e65b1efedc28288700da4a63271ff28b"
#
# $props$time
# [1] "2017-05-13T02:57:06"
#
# $props$current_witness
# [1] "arhag"
#
# $props$total_pow
# [1] 514415
#
# $props$num_pow_witnesses
# [1] 172
#
# $props$virtual_supply
# [1] "250237081.722 STEEM"
#
# $props$current_supply
# [1] "248903602.785 STEEM"
#
# $props$confidential_supply
# [1] "0.000 STEEM"
#
# $props$current_sbd_supply
# [1] "1108120.997 SBD"
#
# $props$confidential_sbd_supply
# [1] "0.000 SBD"
#
# $props$total_vesting_fund_steem
# [1] "180883505.877 STEEM"
#
# ...

# %%
trend_content <- trending$content
trend_content
# Out:
# Error in vapply(seq_along(mapped), function(i) {: values must be length 1,
#  but FUN(X[[40]]) result is length 0
# Traceback:
#
# 1. tryCatch({
#  .     for (mime in getOption("jupyter.display_mimetypes")) {
#  .         r <- mime2repr[[mime]](obj)
#  .         if (!is.null(r))
#  .             data[[mime]] <- r
#  .     }
#  . }, error = handle_error)
# $`andrarchy/if-you-want-to-support-steem-be-on-twitter`
# $`andrarchy/if-you-want-to-support-steem-be-on-twitter`$id
# [1] 2685989
#
# $`andrarchy/if-you-want-to-support-steem-be-on-twitter`$author
# [1] "andrarchy"
#
# $`andrarchy/if-you-want-to-support-steem-be-on-twitter`$permlink
# [1] "if-you-want-to-support-steem-be-on-twitter"
#
# $`andrarchy/if-you-want-to-support-steem-be-on-twitter`$category
# [1] "marketing"
#
# $`andrarchy/if-you-want-to-support-steem-be-on-twitter`$parent_author
# [1] ""
#
# $`andrarchy/if-you-want-to-support-steem-be-on-twitter`$parent_permlink
# [1] "marketing"
#
# ...

# %%
# Out:
# NULL

# %%
# Out:
# NULL

# %%
# Out:
# NULL
